# %%
# https://www.kaggle.com/datasets/gauravduttakiit/airbnb-berlin-price-prediction
# Dies ist eine Übung ohne Fragestellung. 
# Bei einer realen Aufgabenstellung wie "Schätze den Preis von einem gerade zu erstellenden Angebot" müssten andere Annahmen getroffen werden.
# Alles was auf den Host bezogen ist müsste entfernt werden, da dieser Faktor bei einem neuen Angebot nicht vorliegt. Folgerichtig müsste man sich die Frage stelle nwelchen Einfluss die Bewertungen auf den Preis haben und in wie weit dies sich gegenseitig beeinflussen. 
import pandas as pd 
test_df = pd.read_csv("test_airbnb_berlin.csv")
train_df = pd.read_csv("train_airbnb_berlin.csv")

columns_to_drop = []

# %% [markdown]
# # Voranalyse

# %% [markdown]
# ## Reduktion

# %%
# listet ob spalten nur einen Wert haben
unique_count = train_df.nunique() == 1
# set null where more than one value is present and sort them out
cols_with_one_value = unique_count.where(lambda b : b == True).dropna().index.tolist()
columns_to_drop.extend(cols_with_one_value)
cols_with_one_value
# Out:
# ['Listing Name', 'Country Code', 'Country', 'Business Travel Ready']

# %%
train_df = train_df.drop(columns=cols_with_one_value)
train_df.head(3)
# Out:
#    Listing ID      Host ID   Host Name  Host Since Host Response Time  \
# 0  19665213.0  156079597.0  Maximilian  2016-01-20                NaN
# 1   6436842.0    5302290.0       Dulie  2013-04-07                NaN
# 2  10559468.0   59151456.0       Geank  2016-02-07                NaN
#
#   Host Response Rate Is Superhost    neighbourhood Neighborhood Group    City  \
# 0                NaN            f  Prenzlauer Berg             Pankow  Berlin
# 1                NaN            f           Pankow             Pankow  Berlin
# 2                NaN            f  Prenzlauer Berg             Pankow  Berlin
#
#    ... Last Review  Overall Rating  Accuracy Rating Cleanliness Rating  \
# 0  ...  2017-08-08           100.0             10.0               10.0
# 1  ...  2019-04-30            90.0              9.0                9.0
# 2  ...  2016-07-04           100.0             10.0               10.0
#
#   Checkin Rating Communication Rating Location Rating Value Rating  \
# 0           10.0                 10.0             9.0         10.0
# 1           10.0                 10.0             9.0         10.0
# 2           10.0                 10.0            10.0         10.0
#
#   Instant Bookable Price
# 0                t  26.0
# 1                f  41.0
# 2                f  50.0
#
# [3 rows x 35 columns]

# %%
# spalten finden in denen ein Null vorhanden ist
has_nulls = train_df.isnull().any().where(lambda b : b == True).dropna().index.tolist()

# %%
# prozent von Nan-Werten in einer Spalte
percent_missing = train_df.isnull().sum() * 100 / len(train_df)
missing_value_df = pd.DataFrame({'column_name': train_df.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                                column_name  percent_missing
# Listing ID                      Listing ID         0.006373
# Host ID                            Host ID         0.000000
# Host Name                        Host Name         0.140199
# Host Since                      Host Since         0.133826
# Host Response Time      Host Response Time        45.086668
# Host Response Rate      Host Response Rate        45.086668
# Is Superhost                  Is Superhost         0.146572
# neighbourhood                neighbourhood         0.000000
# Neighborhood Group      Neighborhood Group         0.000000
# City                                  City         0.006373
# Postal Code                    Postal Code         1.459342
# Latitude                          Latitude         0.000000
# Longitude                        Longitude         0.000000
# Is Exact Location        Is Exact Location         0.000000
# Property Type                Property Type         0.000000
# Room Type                        Room Type         0.000000
# Accomodates                    Accomodates         0.000000
# Bathrooms                        Bathrooms         0.089217
# Bedrooms                          Bedrooms         0.031863
# Beds                                  Beds         0.050981
# Square Feet                    Square Feet        98.069080
# Guests Included            Guests Included         0.000000
# Min Nights                      Min Nights         0.000000
# Reviews                            Reviews         0.000000
# First Review                  First Review        17.238083
# Last Review                    Last Review        17.244456
# Overall Rating              Overall Rating        18.875860
# Accuracy Rating            Accuracy Rating        18.933214
# Cleanliness Rating      Cleanliness Rating        18.926842
# Checkin Rating              Checkin Rating        18.945960
# Communication Rating  Communication Rating        18.926842
# Location Rating            Location Rating        18.933214
# Value Rating                  Value Rating        18.939587
# Instant Bookable          Instant Bookable         0.000000
# Price                                Price         0.057354

# %%
# alles verwerfen was über 10% lücken hat
over_10_percent = missing_value_df[missing_value_df['percent_missing'] > 10]['column_name'].tolist()
train_df = train_df.drop(columns=over_10_percent)
columns_to_drop.extend(over_10_percent)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15692 entries, 0 to 15691
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Listing ID          15691 non-null  float64
#  1   Host ID             15692 non-null  float64
#  2   Host Name           15670 non-null  object
#  3   Host Since          15671 non-null  object
#  4   Is Superhost        15669 non-null  object
#  5   neighbourhood       15692 non-null  object
#  6   Neighborhood Group  15692 non-null  object
#  7   City                15691 non-null  object
#  8   Postal Code         15463 non-null  object
#  9   Latitude            15692 non-null  float64
#  10  Longitude           15692 non-null  float64
#  11  Is Exact Location   15692 non-null  object
#  12  Property Type       15692 non-null  object
#  13  Room Type           15692 non-null  object
#  14  Accomodates         15692 non-null  object
#  15  Bathrooms           15678 non-null  object
#  16  Bedrooms            15687 non-null  object
#  17  Beds                15684 non-null  object
#  18  Guests Included     15692 non-null  object
#  19  Min Nights          15692 non-null  object
#  20  Reviews             15692 non-null  int64
#  21  Instant Bookable    15692 non-null  object
#  22  Price               15683 non-null  float64
# dtypes: float64(5), int64(1), object(17)
# memory usage: 2.8+ MB

# %%
# semantisch unlogisches entfernen
# aus dem Hostnamen könnte man noch geschlecht oder nationalität ableiten
no_added_value = ['Listing ID', 'Host ID', 'Host Name', 'City', 'Postal Code']
train_df = train_df.drop(columns=no_added_value)
columns_to_drop.extend(no_added_value)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15692 entries, 0 to 15691
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Host Since          15671 non-null  object
#  1   Is Superhost        15669 non-null  object
#  2   neighbourhood       15692 non-null  object
#  3   Neighborhood Group  15692 non-null  object
#  4   Latitude            15692 non-null  float64
#  5   Longitude           15692 non-null  float64
#  6   Is Exact Location   15692 non-null  object
#  7   Property Type       15692 non-null  object
#  8   Room Type           15692 non-null  object
#  9   Accomodates         15692 non-null  object
#  10  Bathrooms           15678 non-null  object
#  11  Bedrooms            15687 non-null  object
#  12  Beds                15684 non-null  object
#  13  Guests Included     15692 non-null  object
#  14  Min Nights          15692 non-null  object
#  15  Reviews             15692 non-null  int64
#  16  Instant Bookable    15692 non-null  object
#  17  Price               15683 non-null  float64
# dtypes: float64(3), int64(1), object(14)
# memory usage: 2.2+ MB

# %% [markdown]
# ## Aufräumen

# %%
# Schauen was ersetzt werden muss
train_df.isnull().any().where(lambda b : b == True).dropna().index.tolist()
# Out:
# ['Host Since', 'Is Superhost', 'Bathrooms', 'Bedrooms', 'Beds', 'Price']

# %% [markdown]
# Host Since -> annahmne = heute
#
# Is Superhost' -> ammahme = false
#
# Bathrooms, Bedrooms, Beds -> annahme = 0
#
# Price -> löschen
#
# Alternativ noch Bewertungen drin lassen aber alles ohne Bewertungen löschen

# %% [markdown]
# ## Anreicherung

# %%
# was kann abgeleitet werden aus den Daten? 
test_df = pd.read_csv("test_airbnb_berlin.csv") # neu laden da sich auch aus lückenhaften angeben noch was ableiten lassen kann
train_df.head(3)
# Out:
#    Host Since Is Superhost    neighbourhood Neighborhood Group  Latitude  \
# 0  2016-01-20            f  Prenzlauer Berg             Pankow  52.54652
# 1  2013-04-07            f           Pankow             Pankow  52.56512
# 2  2016-02-07            f  Prenzlauer Berg             Pankow  52.54741
#
#    Longitude Is Exact Location Property Type        Room Type Accomodates  \
# 0   13.41792                 t     Apartment     Private room           2
# 1   13.42214                 t     Apartment  Entire home/apt           2
# 2   13.42521                 t     Apartment  Entire home/apt           3
#
#   Bathrooms Bedrooms Beds Guests Included Min Nights  Reviews  \
# 0       1.0      1.0  1.0               1          2        6
# 1       1.0      2.0  2.0               2          7        6
# 2       1.0      1.0  2.0               1          1        2
#
#   Instant Bookable  Price
# 0                t   26.0
# 1                f   41.0
# 2                f   50.0

# %% [markdown]
# Host Since -> Monaten an Vermietungszeit
#
# Host Response -> ob er überhaupt jemals reagiert hat oder ordinal aufsteigend
#
# Bewertungen -> ob überhapt schon jemand da war (steckt schon in der Anzahl der Bewertungen)

# %% [markdown]
# # Umsetzten und speichern

# %%
test_df = pd.read_csv("test_airbnb_berlin.csv")
train_df = pd.read_csv("train_airbnb_berlin.csv")

# Der Preis ist nur im Trainingsset
train_df.dropna(subset=['Price'])

def df_process(df_o):
    df = df_o.copy()
    # nulls füllen
    df['Host Since'] = df['Host Since'].fillna('2019-06-01')
    df['Is Superhost'] = df['Is Superhost'].fillna(False)
    df['Bathrooms'] = df['Bathrooms'].fillna(0)
    df['Bedrooms'] = df['Bedrooms'].fillna(0)
    df['Beds'] = df['Beds'].fillna(0)
    
    # die neusten Bewerungen sind aus Mai 2019 also nehmen wir den 01.06.2019 als Vergleichszeitpunkt an
    df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
    df['Host Since'] = (pd.to_datetime('2019-06-01', infer_datetime_format=True) - pd.to_datetime(df['Host Since'], infer_datetime_format=True)) / pd.offsets.Day(1)
    df = df.rename(columns={'Host Since':'Host Since Days'})
    
    # wurde auf nachrichten reagiert
    df['Has Responses'] = df['Host Response Time'] is not None
    
    df = df.drop(columns=columns_to_drop)
    return df
    
test_df = df_process(test_df)
train_df = df_process(train_df)
# Out:
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-04-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-05-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-08-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '23-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-02-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-09-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-08-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '31-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-05-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-09-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-05-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '22-05-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-04-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-02-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '31-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-05-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-10-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '23-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-02-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '23-04-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-07-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-12-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-05-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-05-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '23-09-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-08-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-02-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-05-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-08-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-08-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-03-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-07-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-07-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '22-07-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '31-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-12-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-08-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-05-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-09-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-03-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-07-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '22-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-07-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-06-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-06-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-08-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-07-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '31-05-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-05-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-02-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '22-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-09-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-06-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-07-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-10-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-09-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-05-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '22-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-10-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-09-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-03-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-04-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-07-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-10-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-01-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '23-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-10-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-03-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-05-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-12-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '14-11-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '31-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '23-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '22-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-11-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '18-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '15-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '26-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '30-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '19-10-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '23-11-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '31-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '24-12-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '27-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '29-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '13-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '25-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '28-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '21-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '16-06-2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '20-02-2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)
# C:\Users\sric\AppData\Local\Temp\ipykernel_6968\1651692499.py:17: UserWarning: Parsing '17-12-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Host Since'] = pd.to_datetime(df['Host Since'], infer_datetime_format=True)

# %%
test_df
# Out:
#       Host Since Days Is Superhost    neighbourhood        Neighborhood Group  \
# 0              1812.0            t        Kreuzberg  Friedrichshain-Kreuzberg
# 1              2768.0            f   Friedrichshain  Friedrichshain-Kreuzberg
# 2              3100.0            f   Friedrichshain  Friedrichshain-Kreuzberg
# 3               698.0            f        Tempelhof   Tempelhof - SchÃ¶neberg
# 4              1494.0            f   Friedrichshain  Friedrichshain-Kreuzberg
# ...               ...          ...              ...                       ...
# 7837           1914.0            f  Prenzlauer Berg                    Pankow
# 7838           1673.0            f      SchÃ¶neberg   Tempelhof - SchÃ¶neberg
# 7839           2426.0            t  Prenzlauer Berg                    Pankow
# 7840            822.0            f        NeukÃ¶lln                 NeukÃ¶lln
# 7841           1768.0            f        NeukÃ¶lln                 NeukÃ¶lln
#
#       Latitude  Longitude Is Exact Location Property Type        Room Type  \
# 0     52.50053   13.44184                 t     Apartment  Entire home/apt
# 1     52.51647   13.45862                 t     Apartment  Entire home/apt
# 2     52.52481   13.44676                 f     Apartment     Private room
# 3     52.46009   13.42204                 t     Apartment     Private room
# 4     52.50516   13.45957                 f     Apartment     Private room
# ...        ...        ...               ...           ...              ...
# 7837  52.54392   13.42416                 t     Apartment     Private room
# 7838  52.48460   13.35230                 t     Apartment  Entire home/apt
# 7839  52.54390   13.42881                 t     Apartment  Entire home/apt
# 7840  52.48783   13.42376                 f     Apartment  Entire home/apt
# 7841  52.47130   13.43878                 f     Apartment     Private room
#
#      Accomodates Bathrooms Bedrooms Beds Guests Included Min Nights  Reviews  \
# 0              2         1        1    1               2          2      131
# 1              4       1.5        2    4               2          5       22
# 2              2         1        1    2               1          2       20
# 3              3         1        3    4               1          2       19
# 4              2         1        1    1               1          7        3
# ...          ...       ...      ...  ...             ...        ...      ...
# 7837           2         2        1    1               1          1        0
# 7838           3         1        1    2               1          7        1
# 7839           4         1        1    2               2          3       30
# 7840           3         1        1    1               1         13        1
# 7841           2         1        1    1               1          1        2
#
#      Instant Bookable  Has Responses
# 0                   f           True
# 1                   f           True
# 2                   t           True
# 3                   t           True
# 4                   t           True
# ...               ...            ...
# 7837                f           True
# 7838                f           True
# 7839                f           True
# 7840                f           True
# 7841                f           True
#
# [7842 rows x 18 columns]

# %%
train_df
# Out:
#        Listing ID Listing Name      Host ID   Host Name  Host Since  \
# 0      19665213.0            *  156079597.0  Maximilian  2016-01-20
# 1       6436842.0            *    5302290.0       Dulie  2013-04-07
# 2      10559468.0            *   59151456.0       Geank  2016-02-07
# 3      27215482.0            *  193452785.0        Alix  2018-06-26
# 4      27287546.0            *  205870244.0      Lurina  2013-05-16
# ...           ...          ...          ...         ...         ...
# 15687  12936631.0            *   19460983.0     Ascharl  2013-06-22
# 15688   8207346.0            *   30411910.0       Marki  2015-04-19
# 15689  12246808.0            *   89972306.0         Ada  2016-08-11
# 15690  10886411.0            *   10108952.0       Lanna  2015-12-06
# 15691  32774348.0            *  148795651.0      OloreA  2017-08-07
#
#        Host Response Time Host Response Rate Is Superhost    neighbourhood  \
# 0                     NaN                NaN            f  Prenzlauer Berg
# 1                     NaN                NaN            f           Pankow
# 2                     NaN                NaN            f  Prenzlauer Berg
# 3                     NaN                NaN            f   Friedrichshain
# 4      within a few hours                92%            t  Prenzlauer Berg
# ...                   ...                ...          ...              ...
# 15687  a few days or more                33%            f        Kreuzberg
# 15688                 NaN                NaN            f        NeukÃ¶lln
# 15689                 NaN                NaN            f          Wedding
# 15690        within a day                50%            f      SchÃ¶neberg
# 15691      within an hour               100%            f      Rummelsburg
#
#              Neighborhood Group  ... Overall Rating Accuracy Rating  \
# 0                        Pankow  ...          100.0            10.0
# 1                        Pankow  ...           90.0             9.0
# 2                        Pankow  ...          100.0            10.0
# 3      Friedrichshain-Kreuzberg  ...          100.0            10.0
# 4                        Pankow  ...            NaN             NaN
# ...                         ...  ...            ...             ...
# 15687  Friedrichshain-Kreuzberg  ...           98.0            10.0
# 15688                 NeukÃ¶lln  ...          100.0            10.0
# 15689                     Mitte  ...            NaN             NaN
# 15690   Tempelhof - SchÃ¶neberg  ...           90.0            10.0
# 15691               Lichtenberg  ...            NaN             NaN
#
#       Cleanliness Rating Checkin Rating  Communication Rating  \
# 0                   10.0           10.0                  10.0
# 1                    9.0           10.0                  10.0
# 2                   10.0           10.0                  10.0
# 3                   10.0           10.0                  10.0
# 4                    NaN            NaN                   NaN
# ...                  ...            ...                   ...
# 15687                9.0           10.0                  10.0
# 15688                9.0           10.0                  10.0
# 15689                NaN            NaN                   NaN
# 15690               10.0           10.0                  10.0
# 15691                NaN            NaN                   NaN
#
#        Location Rating Value Rating Instant Bookable Business Travel Ready  \
# 0                  9.0         10.0                t                     f
# 1                  9.0         10.0                f                     f
# 2                 10.0         10.0                f                     f
# 3                 10.0          9.0                f                     f
# 4                  NaN          NaN                t                     f
# ...                ...          ...              ...                   ...
# 15687             10.0         10.0                f                     f
# 15688             10.0          9.0                f                     f
# 15689              NaN          NaN                f                     f
# 15690             10.0          9.0                f                     f
# 15691              NaN          NaN                t                     f
#
#        Price
# 0       26.0
# 1       41.0
# 2       50.0
# 3       50.0
# 4       55.0
# ...      ...
# 15687   45.0
# 15688  130.0
# 15689   19.0
# 15690  100.0
# 15691   29.0
#
# [15692 rows x 39 columns]

# %%
train_df.to_csv('test_airbnb_berlin_preprocessed.csv')
